# %%
from pyfaidx import Fasta
from pyfaidx import Faidx
import numpy  as np
import pandas as pd

# %%
lncRNA_fasta = Fasta('/home/alva/rgtdata/hg38/gencode.v36.lncRNA_transcripts.fa',read_long_names=True)
fa           = Faidx('/home/alva/rgtdata/hg38/gencode.v36.lncRNA_transcripts.fa',read_long_names=True)
index_fasta  = fa.index

# %%
index_fasta
# Out:
# OrderedDict([('ENST00000473358.1|ENSG00000243485.5|OTTHUMG00000000959|OTTHUMT00000002840.1|MIR1302-2HG-202|MIR1302-2HG|712|',
#               IndexRecord(rlen=712, offset=110, lenc=60, lenb=61, bend=834, prev_bend=0)),
#              ('ENST00000469289.1|ENSG00000243485.5|OTTHUMG00000000959|OTTHUMT00000002841.1|MIR1302-2HG-201|MIR1302-2HG|535|',
#               IndexRecord(rlen=535, offset=944, lenc=60, lenb=61, bend=1488, prev_bend=834)),
#              ('ENST00000417324.1|ENSG00000237613.2|OTTHUMG00000000960|OTTHUMT00000002842.1|FAM138A-201|FAM138A|1187|',
#               IndexRecord(rlen=1187, offset=1591, lenc=60, lenb=61, bend=2798, prev_bend=1488)),
#              ('ENST00000461467.1|ENSG00000237613.2|OTTHUMG00000000960|OTTHUMT00000002843.1|FAM138A-202|FAM138A|590|',
#               IndexRecord(rlen=590, offset=2900, lenc=60, lenb=61, bend=3500, prev_bend=2798)),
# ...

# %%
path         = '/home/alva/Documents/lncRNAs_project_2020/Analysis_2021/Tcga_R/GDCdata/TCGA-BRCA/harmonized/Transcriptome_Profiling/Gene_Expression_Quantification/r_data/test.txt'
lncRNAs      = pd.read_csv(path,header=0)
lncRNA_list  = lncRNAs['original_ensembl_gene_id'].to_list()
lncRNA_list
# Out:
# ['ENSG00000000003.13', 'ENSG00000000005.5']

# %%
lncRNA_fasta['ENST00000473358.1|ENSG00000243485.5|OTTHUMG00000000959|OTTHUMT00000002840.1|MIR1302-2HG-202|MIR1302-2HG|712|'].value()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-931677c9be47> in <module>
# ----> 1 lncRNA_fasta['ENST00000473358.1|ENSG00000243485.5|OTTHUMG00000000959|OTTHUMT00000002840.1|MIR1302-2HG-202|MIR1302-2HG|712|'].value()
#
# AttributeError: 'FastaRecord' object has no attribute 'value'

# %%
sample_fasta = []
for header in lncRNA_list:
    sample_fasta.append(index_fasta['ENST00000473358.1|ENSG00000243485.5|OTTHUMG00000000959|OTTHUMT00000002840.1|MIR1302-2HG-202|MIR1302-2HG|712|'])

# %%
sample_fasta
# Out:
# [IndexRecord(rlen=712, offset=110, lenc=60, lenb=61, bend=834, prev_bend=0),
#  IndexRecord(rlen=712, offset=110, lenc=60, lenb=61, bend=834, prev_bend=0)]
